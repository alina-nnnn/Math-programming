# %% [markdown]
# ### Задание 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
class Neuron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias

    def feedforward(self, inputs):
        total = np.dot(self.weights, inputs) + self.bias
        return self.activate(total)

    def activate(self, x):
        return 1 / (1 + np.exp(-x))

class OurNeuralNetwork:
    def __init__(self):
        weights = np.array([0.5, 0.5, 0.5])
        bias = 0
        self.h1 = Neuron(weights, bias)
        self.h2 = Neuron(weights, bias)
        self.h3 = Neuron(weights, bias)
        self.o1 = Neuron(weights, bias)

    def feedforward(self, x1, x2, x3):
        out_h1 = self.h1.feedforward(np.array([x1, x2, x3]))
        out_h2 = self.h2.feedforward(np.array([x1, x2, x3]))
        out_h3 = self.h3.feedforward(np.array([x1, x2, x3]))

        out_o1 = self.o1.feedforward(np.array([out_h1, out_h2, out_h3]))
        return out_o1



# Пример использования
network1 = OurNeuralNetwork()
output1 = network1.feedforward(1, 2, 3)
print(output1)
# Out:
# 0.8067238139969796

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class OurNeuralNetwork2:
    def __init__(self):
        weights = np.array([1, 0])
        bias = 1
        self.h1 = Neuron(weights, bias)
        self.h2 = Neuron(weights, bias)
        self.o1 = Neuron(weights, bias)
        self.o2 = Neuron(weights, bias)

    def feedforward(self, x1, x2):
        out_h1 = self.h1.feedforward(np.array([x1, x2]))
        out_h2 = self.h2.feedforward(np.array([x1, x2]))

        out_o1 = self.o1.feedforward(np.array([out_h1, out_h2]))
        out_o2 = self.o2.feedforward(np.array([out_h1, out_h2]))
        return out_o1, out_o2
    
    
network2 = OurNeuralNetwork2()
output2 = network2.feedforward(1, 2)
print(output2)
# Out:
# (0.8677026536525567, 0.8677026536525567)

# %% [markdown]
# ### Задание 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

class Neuron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias

    def feedforward(self, inputs):
        total = np.dot(self.weights, inputs) + self.bias
        return self.sigmoid(total)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

class NeuralNetworkSigmoid:
    def __init__(self):
        weights = np.array([0.5, 0.5, 0.5])
        bias = 0
        self.h1 = Neuron(weights, bias)
        self.h2 = Neuron(weights, bias)
        self.h3 = Neuron(weights, bias)
        self.o1 = Neuron(weights, bias)

    def feedforward(self, x1, x2, x3):
        out_h1 = self.h1.feedforward(np.array([x1, x2, x3]))
        out_h2 = self.h2.feedforward(np.array([x1, x2, x3]))
        out_h3 = self.h3.feedforward(np.array([x1, x2, x3]))

        out_o1 = self.o1.feedforward(np.array([out_h1, out_h2, out_h3]))
        return out_o1


# Пример использования
network_sigmoid = NeuralNetworkSigmoid()
output_sigmoid = network_sigmoid.feedforward(1, 2, 3)
print(output_sigmoid)
# Out:
# 0.8067238139969796

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

class Neuron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias

    def feedforward(self, inputs):
        total = np.dot(self.weights, inputs) + self.bias
        return self.tanh(total)

    def tanh(self, x):
        return np.tanh(x)

class NeuralNetworkTanh:
    def __init__(self):
        weights = np.array([0.5, 0.5, 0.5])
        bias = 0
        self.h1 = Neuron(weights, bias)
        self.h2 = Neuron(weights, bias)
        self.h3 = Neuron(weights, bias)
        self.o1 = Neuron(weights, bias)

    def feedforward(self, x1, x2, x3):
        out_h1 = self.h1.feedforward(np.array([x1, x2, x3]))
        out_h2 = self.h2.feedforward(np.array([x1, x2, x3]))
        out_h3 = self.h3.feedforward(np.array([x1, x2, x3]))

        out_o1 = self.o1.feedforward(np.array([out_h1, out_h2, out_h3]))
        return out_o1


# Пример использования
network_tanh = NeuralNetworkTanh()
output_tanh = network_tanh.feedforward(1, 2, 3)
print(output_tanh)
# Out:
# 0.903798759264991

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

class Neuron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias

    def feedforward(self, inputs):
        total = np.dot(self.weights, inputs) + self.bias
        return self.relu(total)

    def relu(self, x):
        return np.maximum(0, x)

class NeuralNetworkReLU:
    def __init__(self):
        weights = np.array([0.5, 0.5, 0.5])
        bias = 0
        self.h1 = Neuron(weights, bias)
        self.h2 = Neuron(weights, bias)
        self.h3 = Neuron(weights, bias)
        self.o1 = Neuron(weights, bias)

    def feedforward(self, x1, x2, x3):
        out_h1 = self.h1.feedforward(np.array([x1, x2, x3]))
        out_h2 = self.h2.feedforward(np.array([x1, x2, x3]))
        out_h3 = self.h3.feedforward(np.array([x1, x2, x3]))

        out_o1 = self.o1.feedforward(np.array([out_h1, out_h2, out_h3]))
        return out_o1


# Пример использования
network_relu = NeuralNetworkReLU()
output_relu = network_relu.feedforward(1, 2, 3)
print(output_relu)
# Out:
# 4.5

# %% [markdown]
# ### Задание 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Классификация

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error

# Загрузка данных для классификации
iris_data_url = "https://gist.githubusercontent.com/netj/8836201/raw/"
iris_data = pd.read_csv(iris_data_url)

# %%
# Разделение данных на признаки и целевую переменную
X = iris_data.drop("variety", axis=1)
y = iris_data["variety"]

# Разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# Создание и обучение модели классификации
classifier = MLPClassifier(max_iter=1000, random_state=123)
classifier.fit(X_train, y_train)

# Предсказание классов для тестовых данных
y_pred = classifier.predict(X_test)

# Оценка точности модели
print("Test Accuracy:", classifier.score(X_test, y_test))
print("Training Accuracy:", classifier.score(X_train, y_train))
# Out:
# Test Accuracy: 0.9666666666666667
# Training Accuracy: 0.9833333333333333

# %%
# Атрибуты
print("Убыток после завершения процесса обучения: ", classifier.loss_)
print("Массив длины n_layers-1, где каждый элемент - веса, связанные с уровнем i: ", len(classifier.coefs_))
print("Массив длины n_layers-1, где каждый элемент - перехват, связанный с персептроном слоя i: ", len(classifier.intercepts_))
print("Количество итераций, для которых выполнялась оценка: ", classifier.n_iter_)
print("Имя функции активации выходного слоя: ", classifier.out_activation_)
# Out:
# Убыток после завершения процесса обучения:  0.06884106415956573
# Массив длины n_layers-1, где каждый элемент - веса, связанные с уровнем i:  2
# Массив длины n_layers-1, где каждый элемент - перехват, связанный с персептроном слоя i:  2
# Количество итераций, для которых выполнялась оценка:  630
# Имя функции активации выходного слоя:  softmax

# %% [markdown]
# Регрессия

# %%
# Загрузка данных для регрессии
salary_data_url = "https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linear-regression/master/Salary_Data.csv"
salary_data = pd.read_csv(salary_data_url)

# %%
# Разделение данных на признаки и целевую переменную
X = salary_data["YearsExperience"].values.reshape(-1, 1)
y = salary_data["Salary"]

# Разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# Создание и обучение модели регрессии
regressor = MLPRegressor(max_iter=100000, random_state=123)
regressor.fit(X_train, y_train)

# Предсказание зарплаты для тестовых данных
y_pred = regressor.predict(X_test)

# Оценка точности модели
print("Test Accuracy:", regressor.score(X_test, y_test))
print("Training Accuracy:", regressor.score(X_train, y_train))
# Out:
# Test Accuracy: 0.9711447382244208
# Training Accuracy: 0.9477046223392795

# %%
# Атрибуты
print("Loss: ", regressor.loss_)
print("Number of Coefs: ", len(regressor.coefs_))
print("Number of Intercepts: ", len(regressor.intercepts_))
print("Number of Iterations for Which Estimator Ran: ", regressor.n_iter_)
print("Name of Output Layer Activation Function: ", regressor.out_activation_)
# Out:
# Loss:  16873681.689960103
# Number of Coefs:  2
# Number of Intercepts:  2
# Number of Iterations for Which Estimator Ran:  30344
# Name of Output Layer Activation Function:  identity
